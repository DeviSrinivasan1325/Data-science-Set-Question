# %%
import seaborn as sns
import numpy as np
import pandas as pd

data = pd.DataFrame({
    'Age': [25, 30, 35, 40, 45],
    'BMI': [22.4, 23.0, 25.5, 26.0, 28.3],
    'Blood_Pressure': [120, 122, 124, 130, 135]
})

correlation_matrix = np.corr(data)
sns.heatmap(correlation_matrix, annot=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 11
#       3 import pandas as pd
#       5 data = pd.DataFrame({
#       6     'Age': [25, 30, 35, 40, 45],
#       7     'BMI': [22.4, 23.0, 25.5, 26.0, 28.3],
#       8     'Blood_Pressure': [120, 122, 124, 130, 135]
#       9 })
# ---> 11 correlation_matrix = np.corr(data)
#      12 sns.heatmap(correlation_matrix, annot=True)
#
# File ~\anaconda3\envs\aiml\Lib\site-packages\numpy\__init__.py:427, in __getattr__(attr)
#     424     import numpy.char as char
#     425     return char.chararray
# --> 427 raise AttributeError("module {!r} has no attribute "
#     428                      "{!r}".format(__name__, attr))
#
# AttributeError: module 'numpy' has no attribute 'corr'

# %%
#Ans: np.corr() is not a correct function which is not defined in numpy. Correct it as data.corr().
import seaborn as sns
import numpy as np
import pandas as pd

data = pd.DataFrame({
    'Age': [25, 30, 35, 40, 45],
    'BMI': [22.4, 23.0, 25.5, 26.0, 28.3],
    'Blood_Pressure': [120, 122, 124, 130, 135]
})

correlation_matrix = data.corr()
sns.heatmap(correlation_matrix,cmap='Blues', annot=True)
# Out:
# <Axes: >

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

data = pd.DataFrame({
    'Region': ['North', 'South', 'East', 'West', 'North', 'South', 'East', 'West'],
    'Product': ['A', 'A', 'A', 'A', 'B', 'B', 'B', 'B'],
    'Sales': [200, 220, 250, 240, 180, 210, 230, 220]
})

sns.barplot(x='Region', y='Product', data=data)
plt.title('Product Sales by Region')
plt.show()

# %%
#Ans: instead of bar plot we can use box plot for better outlier dectection and understanding
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

data = pd.DataFrame({
    'Region': ['North', 'South', 'East', 'West', 'North', 'South', 'East', 'West'],
    'Product': ['A', 'A', 'A', 'A', 'B', 'B', 'B', 'B'],
    'Sales': [200, 220, 250, 240, 180, 210, 230, 220]
})

sns.boxplot(x='Region', y='Product', data = data)
plt.title('Product Sales by Region')
plt.show()

# %%
import pandas as pd

data = pd.DataFrame({
    'Transaction': [1, 2, 3, 4, 5],
    'Amount': [100, 200, None, 400, 500],
    'Fraud': [0, 1, 0, 1, 0]
})

data['Amount'].fillna('Missing', inplace=True)
mean_value = data['Amount'].mean()
print(f"Mean Transaction Amount: {mean_value}")
# Out:
# C:\Users\PAVAN\AppData\Local\Temp\ipykernel_12900\3626434856.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Amount'].fillna('Missing', inplace=True)
# C:\Users\PAVAN\AppData\Local\Temp\ipykernel_12900\3626434856.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Missing' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   data['Amount'].fillna('Missing', inplace=True)
# ...

# %%
#Ans: We have to fill the missing value based on the purpose of feature. Since amount key has none value, instead replacing with 'Missing', replace with meaningfull value such as 0. 
import pandas as pd

data = pd.DataFrame({
    'Transaction': [1, 2, 3, 4, 5],
    'Amount': [100, 200, None, 400, 500],
    'Fraud': [0, 1, 0, 1, 0]
})

data['Amount'].fillna(0, inplace=True)
mean_value = data['Amount'].mean()
print(f"Mean Transaction Amount: {mean_value}")
# Out:
# Mean Transaction Amount: 240.0
# C:\Users\PAVAN\AppData\Local\Temp\ipykernel_12900\262992477.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Amount'].fillna(0, inplace=True)

# %%
import pandas as pd
import numpy as np

data = pd.DataFrame({'Values': [10, 12, 15, 18, 120, 14, 13, 16, 17, 150]})

Q1 = data['Values'].quantile(0.25)
Q3 = data['Values'].quantile(0.75)

filtered_data = data[(data['Values'] < Q1 - 1.5 * IQR) | (data['Values'] > Q3 + 1.5 * IQR)]

print("Filtered Data without Outliers:")
print(filtered_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 9
#       6 Q1 = data['Values'].quantile(0.25)
#       7 Q3 = data['Values'].quantile(0.75)
# ----> 9 filtered_data = data[(data['Values'] < Q1 - 1.5 * IQR) | (data['Values'] > Q3 + 1.5 * IQR)]
#      11 print("Filtered Data without Outliers:")
#      12 print(filtered_data)
#
# NameError: name 'IQR' is not defined

# %%
#Ans: IQR is missing to calculate outlier. use IQR=Q3-Q1. also for filtered data which is without a outlier data condition are wrong.
import pandas as pd
import numpy as np

data = pd.DataFrame({'Values': [10, 12, 15, 18, 120, 14, 13, 16, 17, 150]})

Q1 = data['Values'].quantile(0.25)
Q3 = data['Values'].quantile(0.75)
#print(Q1,Q3)

IQR = Q3-Q1
#print(IQR)
filtered_data = data[(data['Values'] > Q1 - 1.5 * IQR) & (data['Values'] < Q3 + 1.5 * IQR)]

print("Filtered Data without Outliers:")
print(filtered_data)
# Out:
# Filtered Data without Outliers:
#    Values
# 0      10
# 1      12
# 2      15
# 3      18
# 5      14
# 6      13
# 7      16
# 8      17

# %%
import pandas as pd
from scipy import stats

data = pd.DataFrame({
    'Region': ['North', 'South', 'East', 'West', 'North', 'South', 'East', 'West'],
    'Sales': [200, 220, 250, 240, 180, 210, 230, 220]
})

north_sales = data[data['Region'] == 'North']['Sales']
south_sales = data[data['Region'] == 'South']['Sales']
east_sales = data[data['Region'] == 'East']['Sales']
west_sales = data[data['Region'] == 'West']['Sales']

f_stat, p_value = stats.f_oneway(north_sales, south_sales, east_sales, west_sales)
print(f"F-Statistic: {f_stat}, P-Value: {p_value}")
# Out:
# F-Statistic: 5.820512820512821, P-Value: 0.06093318474731915

# %%
#Ans: There is no error, code is executed and provided p- value 0.06 which is greater than 0.05, it fails to reject the null hypothesis. there is no significant differences.
import pandas as pd
from scipy import stats

data = pd.DataFrame({
    'Region': ['North', 'South', 'East', 'West', 'North', 'South', 'East', 'West'],
    'Sales': [200, 220, 250, 240, 180, 210, 230, 220]
})

north_sales = data[data['Region'] == 'North']['Sales']
south_sales = data[data['Region'] == 'South']['Sales']
east_sales = data[data['Region'] == 'East']['Sales']
west_sales = data[data['Region'] == 'West']['Sales']

f_stat, p_value = stats.f_oneway(north_sales, south_sales, east_sales, west_sales)
print(f"F-Statistic: {f_stat}, P-Value: {p_value}")
